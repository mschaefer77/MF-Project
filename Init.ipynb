# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.61-py2.py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 117.9/117.9 kB 13.8 MB/s eta 0:00:00
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 109.5/109.5 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 4)) (2.1.4)
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (1.25.2)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 6)) (3.6.3)
# Requirement already satisfied: plotly in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 7)) (6.0.1)
# Collecting yahoofinancials
#   Downloading yahoofinancials-1.20.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 51.9/51.9 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: seaborn in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 9)) (0.13.2)
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 10.8/10.8 MB 66.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 11)) (1.9.3)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 12)) (1.1.3)
# Requirement already satisfied: pytz>=2022.5 in /root/venv/lib/python3.10/site-packages (from yfinance->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: protobuf>=3.19.0 in /root/venv/lib/python3.10/site-packages (from yfinance->-r ./requirements.txt (line 2)) (4.25.7)
# Requirement already satisfied: platformdirs>=2.0.0 in /root/venv/lib/python3.10/site-packages (from yfinance->-r ./requirements.txt (line 2)) (4.3.7)
# Collecting websockets>=13.0
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 181.6/181.6 kB 22.1 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 117.4/117.4 kB 22.6 MB/s eta 0:00:00
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 187.3/187.3 kB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.31 in /root/venv/lib/python3.10/site-packages (from yfinance->-r ./requirements.txt (line 2)) (2.32.3)
# Collecting curl_cffi>=0.7
#   Downloading curl_cffi-0.11.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 8.5/8.5 MB 73.9 MB/s eta 0:00:00
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━��━━━━━━━━━━━━━━ 3.0/3.0 MB 70.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: lxml in /root/venv/lib/python3.10/site-packages (from pandas_datareader->-r ./requirements.txt (line 3)) (5.4.0)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas->-r ./requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from pandas->-r ./requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (4.57.0)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.10/site-packages (from plotly->-r ./requirements.txt (line 7)) (1.38.0)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 232.9/232.9 kB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn->-r ./requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: joblib>=1.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn->-r ./requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /root/venv/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance->-r ./requirements.txt (line 2)) (4.13.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /root/venv/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance->-r ./requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: cffi>=1.12.0 in /root/venv/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance->-r ./requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r ./requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests>=2.31->yfinance->-r ./requirements.txt (line 2)) (3.10)
# Requirement already satisfied: pycparser in /root/venv/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance->-r ./requirements.txt (line 2)) (2.22)
# Building wheels for collected packages: yahoofinancials, peewee
#   Building wheel for yahoofinancials (setup.py): started
#   Building wheel for yahoofinancials (setup.py): finished with status 'done'
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.20-py3-none-any.whl size=38618 sha256=06dde546cae82cfb7040e6b2821a53b22a7efc94fd49cb474198541b0518066f
#   Stored in directory: /root/.cache/pip/wheels/cc/6b/dd/7ff776de4ebf7b144bb9562a813be59d0108306f368af9b637
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-cp310-cp310-linux_x86_64.whl size=971106 sha256=d21720feb352b3338150ec9c5fe1f59623f3574d16dcf9509a85f554acfb07d7
#   Stored in directory: /root/.cache/pip/wheels/8d/c2/af/d591c26196f80ecdedb79664b51642ff1cf49af64d5cd69999
# Successfully built yahoofinancials peewee
# Installing collected packages: peewee, multitasking, appdirs, websockets, soupsieve, patsy, frozendict, curl_cffi, beautifulsoup4, yfinance, yahoofinancials, statsmodels, pandas_datareader
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.13.4 curl_cffi-0.11.1 frozendict-2.4.6 multitasking-0.0.11 pandas_datareader-0.10.0 patsy-1.0.1 peewee-3.18.1 soupsieve-2.7 statsmodels-0.14.4 websockets-15.0.1 yahoofinancials-1.20 yfinance-0.2.61
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
